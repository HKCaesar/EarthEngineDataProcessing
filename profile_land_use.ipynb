# %%
import cProfile
import scripts.read_land_use_no_gdal as rlu

# %%
cProfile.run('rlu.read_land_use()')
# Out:
#          1547065 function calls (1547037 primitive calls) in 9.991 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      3648    0.003    0.000    0.004    0.000 <frozen importlib._bootstrap>:996(_handle_fromlist)
#         1    0.014    0.014    9.991    9.991 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1257(debug)
#         1    0.000    0.000    0.000    0.000 __init__.py:1501(getEffectiveLevel)
#         1    0.000    0.000    0.000    0.000 __init__.py:1515(isEnabledFor)
#         1    0.000    0.000    0.000    0.000 __init__.py:166(translation)
#         1    0.000    0.000    0.000    0.000 __init__.py:182(scale)
#         1    0.000    0.000    0.000    0.000 __init__.py:241(parse_paths)
#         1    0.000    0.000    0.000    0.000 __init__.py:261(to_gdal)
#         1    0.000    0.000    0.000    0.000 __init__.py:374(__mul__)
# ...
