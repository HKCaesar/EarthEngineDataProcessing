# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scripts.read_land_use_no_gdal as rlu
import scripts.read_image_data_scaleable as rid

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# from importlib import reload
# reload(rid)

# %%
polygon = "POLYGON ((144.0229424345357 -37.55299953752239, 144.02019905996406 -37.97282887730929, 144.6632499098556 -37.972670022747636, 144.66240633494579 -37.552454710108975, 144.0229424345357 -37.55299953752239))"
array, classes = rlu.read_land_use(da_shapefile="SDM324649_full/ll_gda94/sde_shape/whole/VIC/CATCHMENTS/layer/landuse_2014.shp",
                  resolution=(2387, 1976),
                  area_filter=polygon,
                  buffer=-0.0001,
                  processes=8)

# %%
# plt.imshow(array)

# %%
train = rid.old_data_preprocess_workflow(image_dir='area3/2014/images/', 
                                 mask_dir='area3/2014/masks/', 
                                 table_dir='area3/2014/tables/LC8_SR.csv', 
                                 new_table_dir='area3/2015/tables/LC8_SR.csv', 
                                 shelve_root_dir='models/area3/shelves/', 
                                 labels=array, 
                                 processes=8, 
                                 max_days_apart=30, 
                                 step=250000)
# Out:
# reading data...
# reading new timestamps...
# interpolating images...
# storing sets...
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08b00>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
# combining sets...
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbdc88>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbdf98>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbdac8>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbdcc0>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcff27fd0>>
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self._os.chmod(file, self._mode)
#     self.dict.sync()
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08748>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08240>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
# Traceback (most recent call last):
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.close()
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._commit()
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbde80>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbd5c0>>
# Traceback (most recent call last):
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbdf28>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.close()
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.close()
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self.dict.sync()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbdda0>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08518>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08080>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08e48>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
# Traceback (most recent call last):
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self._chmod(self._dirfile)
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self._os.chmod(file, self._mode)
#     self.sync()
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcff27cf8>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcff27b70>>
# Traceback (most recent call last):
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcff27d30>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbd6a0>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
# Traceback (most recent call last):
# Traceback (most recent call last):
#     self.close()
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#     self.dict.sync()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.close()
#     self.dict.sync()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._commit()
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe081d0>>
# Traceback (most recent call last):
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08c18>>
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self._chmod(self._dirfile)
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self._os.chmod(file, self._mode)
#     self.dict.close()
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbddd8>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbd828>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self._commit()
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08898>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08278>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
#     self.close()
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcff27d30>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcff27c50>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbdda0>>
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.sync()
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self.dict.sync()
#     self.dict.sync()
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#     self._chmod(self._dirfile)
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbdac8>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbd828>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbde80>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbdef0>>
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#     self.dict.close()
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#     self._commit()
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
#     self._os.chmod(file, self._mode)
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe084a8>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08080>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe084a8>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self._chmod(self._dirfile)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._commit()
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcff27cf8>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcff27cc0>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.close()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self.sync()
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcff27fd0>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcff27f60>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcff27ef0>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
# Traceback (most recent call last):
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.dict.sync()
# Traceback (most recent call last):
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.close()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self.sync()
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08cf8>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe086d8>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08fd0>>
#     self.dict.sync()
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbdf98>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbd6a0>>
# Traceback (most recent call last):
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbdcc0>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.sync()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08898>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08748>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcff27b38>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcff271d0>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.close()
#     self.close()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self._os.chmod(file, self._mode)
#     self.dict.close()
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self._commit()
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08e10>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe081d0>>
# Traceback (most recent call last):
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.close()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbde80>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f4000fbdf28>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f3fcfe08240>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.close()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.dict.close()
#     self.dict.close()
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#     self._commit()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._commit()

# %%
train['0'].shape
# Out:
# (250000, 157)
