# %%
import sys
sys.path.append('../')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scripts.read_land_use_no_gdal as rlu
import scripts.read_image_data_scaleable as rid

# %%
# from importlib import reload
# reload(rid)

# %%
polygon = "POLYGON ((144.0229424345357 -37.55299953752239, 144.02019905996406 -37.97282887730929, 144.6632499098556 -37.972670022747636, 144.66240633494579 -37.552454710108975, 144.0229424345357 -37.55299953752239))"
array, classes = rlu.read_land_use(da_shapefile="SDM324649_full/ll_gda94/sde_shape/whole/VIC/CATCHMENTS/layer/landuse_2014.shp",
                  resolution=(2387, 1976),
                  area_filter=polygon,
                  buffer=-0.0001,
                  processes=8)

# %%
# plt.imshow(array)

# %%
train = rid.old_data_preprocess_workflow(image_dir='area3/2014/images/', 
                                 mask_dir='area3/2014/masks/', 
                                 table_dir='area3/2014/tables/LC8_SR.csv', 
                                 new_table_dir='area3/2015/tables/LC8_SR.csv', 
                                 shelve_root_dir='models/area3/shelves/', 
                                 labels=array, 
                                 processes=8, 
                                 max_days_apart=30, 
                                 step=250000)
# Out:
# reading data...
# reading new timestamps...
# interpolating images...
# storing sets...
# combining sets...
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff19b0>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3fe6828>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self._os.chmod(file, self._mode)
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1a58>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff17f0>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3fe6c88>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1860>>
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self._chmod(self._dirfile)
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self._os.chmod(file, self._mode)
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self.close()
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0bbdd8d400>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1780>>
# Traceback (most recent call last):
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1f28>>
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba4056208>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1860>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff6d68>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff19b0>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1898>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.close()
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.close()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.dict.close()
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self._commit()
#     self._os.chmod(file, self._mode)
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
#     self._os.chmod(file, self._mode)
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1a20>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff17f0>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff6240>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff6828>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1898>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0bbdd8d9b0>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0bbdd8dbe0>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
# Traceback (most recent call last):
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1dd8>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff6e80>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1898>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff6630>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff6e80>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff6e80>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0bbdd8dd30>>
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff6e10>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1898>>
# Traceback (most recent call last):
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1048>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.dict.close()
#     self._chmod(self._dirfile)
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self._commit()
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._chmod(self._dirfile)
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff67f0>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff6780>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba4056080>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff6898>>
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self.close()
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self._commit()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._chmod(self._dirfile)
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._chmod(self._dirfile)
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1860>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff1898>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# Traceback (most recent call last):
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff6898>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f0ba3ff19b0>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
