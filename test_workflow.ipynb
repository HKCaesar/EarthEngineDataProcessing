# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scripts.read_land_use_no_gdal as rlu
import scripts.read_image_data_scaleable as rid

# %%
# from importlib import reload
# reload(rid)

# %%
polygon = "POLYGON ((144.0229424345357 -37.55299953752239, 144.02019905996406 -37.97282887730929, 144.6632499098556 -37.972670022747636, 144.66240633494579 -37.552454710108975, 144.0229424345357 -37.55299953752239))"
array, classes = rlu.read_land_use(da_shapefile="SDM324649_full/ll_gda94/sde_shape/whole/VIC/CATCHMENTS/layer/landuse_2014.shp",
                  resolution=(2387, 1976),
                  area_filter=polygon,
                  buffer=-0.0001,
                  processes=8)

# %%
# plt.imshow(array)

# %%
train = rid.old_data_preprocess_workflow(image_dir='area3/2014/images/', 
                                 mask_dir='area3/2014/masks/', 
                                 table_dir='area3/2014/tables/LC8_SR.csv', 
                                 new_table_dir='area3/2015/tables/LC8_SR.csv', 
                                 shelve_root_dir='models/area3/shelves/', 
                                 labels=array, 
                                 processes=8, 
                                 max_days_apart=30, 
                                 step=250000)
# Out:
# reading data...
# reading new timestamps...
# interpolating images...
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb6d630>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
# storing sets...
# combining sets...
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb6d0f0>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self.dict.close()
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f87469088d0>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb6d748>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66eb8>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66c18>>
# Traceback (most recent call last):
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66dd8>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.dict.close()
#     self.close()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._os.chmod(file, self._mode)
#     self._commit()
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.sync()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self.dict.sync()
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66c18>>
# Traceback (most recent call last):
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb6dac8>>
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66b00>>
#     self.dict.sync()
#     self.close()
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
#     self.close()
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66630>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb6d278>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb6d278>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb6db70>>
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.dict.sync()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._os.chmod(file, self._mode)
#     self._chmod(self._dirfile)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb6d630>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f87469086a0>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f87469082b0>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f8746908908>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb6d0f0>>
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#     self.close()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self._commit()
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self.sync()
#     self._os.chmod(file, self._mode)
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f87035c0e48>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66630>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f87035c0ef0>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.sync()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.sync()
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._commit()
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self.close()
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb6d048>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66630>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb6d550>>
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f8746908cc0>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb6d128>>
#     self._commit()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f8746908e48>>
#     self.close()
#     self._chmod(self._dirfile)
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._os.chmod(file, self._mode)
#     self._commit()
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
# Traceback (most recent call last):
#     self._chmod(self._dirfile)
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._os.chmod(file, self._mode)
#     self.close()
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66ba8>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66828>>
# Traceback (most recent call last):
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f87035c0ef0>>
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#     self.sync()
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 144, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 172, in sync
#     self.dict.sync()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
#     self._commit()
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66e10>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66630>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66d30>>
# Exception ignored in: <bound method Shelf.__del__ of <shelve.DbfilenameShelf object at 0x7f872cb66c50>>
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
# Traceback (most recent call last):
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 162, in __del__
#     self.close()
#   File "/home/mithrillion/anaconda3/lib/python3.5/shelve.py", line 146, in close
#     self.dict.close()
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self.dict.close()
#     self._os.chmod(file, self._mode)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 262, in close
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'
#     self._commit()
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 124, in _commit
#     self._chmod(self._dirfile)
#   File "/home/mithrillion/anaconda3/lib/python3.5/dbm/dumb.py", line 270, in _chmod
#     self._os.chmod(file, self._mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'models/area3/shelves/old/pixels.dir'

# %%
train['0'].shape
# Out:
# (250000, 157)
